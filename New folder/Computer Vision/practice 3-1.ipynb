# %% [markdown]
# # integration of brightness and contrast

# %%
from PIL import Image #import Image module from PIL

# %%
from PIL import ImageEnhance # import ImageEhance module from PIL

# %%
img = Image.open("newastronaut.png") # relative path or absolute path

# %%
display(img) # alternative way to show the read in image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x2813FDE4550>

# %%
img.show()

# %%
print(img.size)
# Out:
# (512, 512)

# %%
print(img.format, img.size, img.mode)
# Out:
# PNG (512, 512) RGB

# %% [markdown]
# # brightness enhancement

# %%
enhancer = ImageEnhance.Brightness(img)

# %%
enhancer.enhance(1.5).show()

# %%
display(enhancer.enhance(1.5))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x281414503A0>

# %%
enhancer.enhance(1.5).save('br-1.png')

# %% [markdown]
# # contrast enhancement

# %%
img = Image.open("br-1.png") # read in the brightnes enhanced imgage

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x2813FEE2250>

# %%
enhancer = ImageEnhance. Contrast(img) # praparing the contrast enhancement

# %%
enhancer.enhance(0.5).show()

# %%
display(enhancer.enhance(0.5))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x28141450D30>

# %% [markdown]
# # another method for combination

# %%
img = Image.open("newastronaut.png") # read in the image ready for enhancement

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x28141450880>

# %%
enhancer=ImageEnhance. Brightness(img)

# %%
img1=enhancer.enhance(1.5)

# %%
enhancer2=ImageEnhance. Contrast(img1)

# %%
img2=enhancer2.enhance(0.5)

# %%
display(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x28141450DC0>

# %% [markdown]
# # draw line

# %%
from PIL import Image

# %%
img = Image.open("newastronaut.png") # read in image image

# %%
import math 
from PIL import Image, ImageDraw  # inport modules

# %%
img1 = ImageDraw.Draw(img)  # create draw img1 into read img

# %%
w, h = 512, 512
shape = [(1, 1), (w - 0, h - 0)] #  define the draw area, first bracket shows the start point, the second bracket shows the end point

# %%
img1.line(shape, fill ="blue", width =10)

# %%
# show the result

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x281414501C0>

# %%
w, h = 512, 512
shape = [(512, 1), (w - 512, h - 0)] #  define the draw area, first bracket shows the start point, the second bracket shows the end point

# %%
img1.line(shape, fill ="blue", width= 50) # color code:https://www.w3schools.com/html/html_colors_hex.asp

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x281414501C0>
