# %% [markdown]
# # scikit-image application

# %%
from skimage import io # import io module from skimage library

# %%
img = io.imread("newastronaut.png") # apply imread() function  from io module

# %%
io.imshow(img) # apply imshow function

# %%
type(img)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %% [markdown]
# # import the image file (data) from skimage

# %%
from skimage import data

# %%
img=data.astronaut()

# %%
io.imshow(img)

# %%
img1=data.chelsea()

# %%
io.imshow(img1)

# %%
print(img.shape)
# Out:
# (512, 512, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
type(img1)
# Out:
# numpy.ndarray

# %%
io.imsave('1012astronaut.png', img)

# %%
imgnew=Image.open('1012astronaut.png')

# %%
display(imgnew)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x1D58C22A4C0>

# %%
print(imgnew.mode)
# Out:
# RGB
