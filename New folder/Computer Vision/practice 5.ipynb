# %% [markdown]
# # data module rview

# %%
from skimage import data,io,color

# %%
img=data.astronaut()

# %%
io.imshow(img)

# %%
print(img.shape)
# Out:
# (512, 512, 3)

# %%
img1=data.coffee()

# %%
io.imshow(img1)

# %%
print(img1.shape)
# Out:
# (400, 600, 3)

# %%
img_hsv = color.rgb2hsv(img)

# %%
io.imshow(img_hsv)

# %%
img1_hsv= color.rgb2hsv(img1)

# %%
io.imshow(img1_hsv)

# %%
img2= data.camera()

# %%
io.imshow(img2)

# %%
img3=data.text()

# %%
io.imshow(img3)

# %%
io.imshow(data.coins())

# %%
img4=io.imread('newastronaut.png')

# %%
io.imshow(img4)

# %%
type(img4)
# Out:
# numpy.ndarray

# %%
gray_img= color.rgb2gray(img4)

# %%
io.imshow(gray_img)

# %%
print(img4.shape)
# Out:
# (512, 512, 3)
